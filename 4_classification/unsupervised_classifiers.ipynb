# %% [markdown]
# # Sentiment Analysis
#
# Evaluating unsupervised learing models
# * vader classifier
# * textblob classifier

# %% [markdown]
# ## Install and import required libraries

# %%
import numpy as np
import pandas as pd 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## Read dataset

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/cz4034 IR project/classifier/XGBoost/label_dataset_fix.csv', lineterminator='\r')

df.head()
# Out:
#        Datetime  Quarter  Likes                    NFT  \
# 0  \n2022-06-27       22      2  Mutant Ape Yacht Club
# 1  \n2023-02-11       31      2  Mutant Ape Yacht Club
# 2  \n2022-12-30       24      0  Mutant Ape Yacht Club
# 3  \n2022-12-29       24      0  Mutant Ape Yacht Club
# 4  \n2022-12-29       24      1  Mutant Ape Yacht Club
#
#                                                 Text  \
# 0  🧪 Mutant Ape Yacht Club | #MAYC #NFT\n\n#27894...
# 1  🐳1 Mutant Ape Yacht Club bought for Ξ15.377\n\...
# 2  🧪 Mutant Ape Yacht Club | #MAYC #NFT\n\n#77 so...
# 3  🧪 Mutant Ape Yacht Club | #MAYC #NFT\n\n#23452...
# 4  Mutant Ape Yacht Club #27908 sold for 17 ETH (...
#
#                                           Clean Text vader textblob  \
# 0          mutant ape yacht club mayc nft sold eth k   neu      neu
# 1  mutant ape yacht club bought floor h chg floor...   neu      neu
# 2          mutant ape yacht club mayc nft sold eth k   neu      neu
# ...

# %% [markdown]
# ## Vader

# %%
print('vader accuracy: ')
print(accuracy_score(df['vader'], df['Polarity (Reviewer 1)']))
# Out:
# vader accuracy:
# 0.444

# %%
print(classification_report(df['vader'], df['Polarity (Reviewer 1)']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.53      0.27      0.36       214
#          neu       0.49      0.26      0.34       965
#          pos       0.42      0.70      0.52       821
#
#     accuracy                           0.44      2000
#    macro avg       0.48      0.41      0.41      2000
# weighted avg       0.47      0.44      0.42      2000

# %% [markdown]
# ## Textblob

# %%
print('textblob accuracy: ')
print(accuracy_score(df['textblob'], df['Polarity (Reviewer 1)']))
# Out:
# textblob accuracy:
# 0.3725

# %%
print(classification_report(df['textblob'], df['Polarity (Reviewer 1)']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.41      0.14      0.21       327
#          neu       0.42      0.22      0.29       970
#          pos       0.35      0.69      0.47       703
#
#     accuracy                           0.37      2000
#    macro avg       0.39      0.35      0.32      2000
# weighted avg       0.39      0.37      0.34      2000
